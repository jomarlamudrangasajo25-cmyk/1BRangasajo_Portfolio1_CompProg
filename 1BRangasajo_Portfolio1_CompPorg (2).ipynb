# %% [markdown]
# JOMAR L. RANGASAJO (BSChE
# PORTFOLIO 1: LIST INPUT/EXPRESSIONS
# THERMAL ENERGY CALCULATOR
#
# In many chemistry laboratory activties, measuring the flow of heat into or out of
# a system is important for understanding chemical reactions.
# Because these calculations require multiple variables like mass,
# specific heat capacity, and temperature change, an automatic calculator becomes
# a necessary tool for reducing human error.

# %%
Nameofprocessorsolute=input('Name of Process or Solute:')
m=input('Mass of solution (in grams):')
c=input('Specifc Heat Capacity of the Solution (J/g°C):')
t1=input('Initial Temperature (°C):')
t2=input('Final Temperature (°C):')
t=float(t2)-float(t1)
print('Change in Temperature:', float(t))
q=float(m)*float(c)*float(t)
print('The amount of heat energy transferred (J) is:', float(q))
# Out:
# Name of Process or Solute: Heating of Water
# Mass of solution (in grams): 100
# Specifc Heat Capacity of the Solution (J/g°C): 4.184
# Initial Temperature (°C): 20
# Final Temperature (°C): 30
# Change in Temperature: 10.0
# The amount of heat energy transferred (J) is: 4184.0
